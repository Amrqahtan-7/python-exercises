# %%
def squares_of_even(nums):
    return [x**2 for x in nums if x % 2 == 0]

print(squares_of_even([1, 2, 3, 4, 5, 6]))

# here is a comment for the new device to use simulate a pull
# Out:
# [4, 16, 36]
